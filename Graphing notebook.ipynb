# %%
import matplotlib.pyplot as plt
import pandas as pd

# Set your x and y markers that appear at the end of the positive x and y axis lines.
xmarker = 'x '
ymarker = 'y '
# Change your labels
x_label = ''
y_label = ''
title = ''
# Choose an appropriate step between x and y ticks.
step = 1
# Set your x_axis and initialise the empty y_axis.
x_axis = [-2,-1,0,1,2]
y_axis = []
# Iterate over x_axis.
for x in x_axis:
    # EQUATION IS ENTERED HERE.
    y = 4 * x -5
    # Append result to y_axis list.
    y_axis.append(y)
# X and Y ticks.
xticks = list(range(min(x_axis)-step,max(x_axis)+step,step))
yticks = list(range(min(y_axis)-step,max(y_axis)+step,step))
# Change figure size/
plt.figure(figsize=(10,8))
# Plot the graph.
plt.plot(x_axis,y_axis,marker='o',markersize=10)
# Change the margin.
plt.margins(x=0.1,y=0.1)
#Alter your x,y labels and title.
plt.xlabel(xlabel=x_label,fontsize=10)
plt.ylabel(ylabel=y_label,fontsize=10)
plt.title(label=title)
# Vertical and horizontal center lines.
plt.axhline(y = 0, color = 'black', linestyle = '-') 
plt.axvline(x = 0, color = 'black', linestyle = '-') 
# Annotate the end of the vertical and horizontal lines with your designated markers.
plt.text(
        # Xaxis
        xticks[-1]+(step/3),
        # Yaxis
        -0.3,
        xmarker,
        fontsize=10)
plt.text(
        # Xaxis
        -0.1,
        # Yaxis
        yticks[-1]+(step/3),
        ymarker,
        fontsize=10)
# Annotate the center lines with the x and y ticks and draw a grid.
for x in xticks:
    if x != 0:
        plt.text(x,step/10,x,rotation=0)
        plt.axvline(x = x, color = 'grey', linestyle = '--')
for y in yticks:
    plt.text(step/20,y,y,rotation=0)
    if y != 0:
        plt.axhline(y = y, color = 'grey', linestyle = '--') 
# Remove default x and y ticks.
plt.xticks([],fontsize=14)
plt.yticks([],fontsize=14)
# Create the table.
table = pd.DataFrame({
    'X Axis':x_axis,
    'Y Axis':y_axis
})
# Print the table.
print(table)
# Display the graph.
plt.show()
# Out:
#    X Axis  Y Axis
# 0      -2     -13
# 1      -1      -9
# 2       0      -5
# 3       1      -1
# 4       2       3
